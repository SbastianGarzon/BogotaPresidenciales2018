# %%
# %pylab inline
import pandas as pd
import os
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Construcción base de datos:

# %%
#Inicializo las columnas con los nombres de las localidades que ya tienen datos
localidades=os.listdir("Votaciones_localidades")
Nombreslocalidades=[]
for i in localidades:
    Nombreslocalidades.append(i[:-7])
df = pd.DataFrame(columns=[Nombreslocalidades])
df= df.rename_axis(None)

# %%
#Algoritmo que ingresa los datos a la tabla, la tabla solo contiene las localidades reportadas.
partidos=('Gustavo Petro','Promotores Blanco','Ivan Duque','Humberto De la Calle','Jorge Trujillo','Sergio Fajardo','Viviane Morales','German Vargas Lleras','Potencial Votantes','Blanco','Nulos','No Marcados','Referencia:')
for i in localidades:
    temp=pd.read_csv("Votaciones_localidades/"+str(i))
    temp.index = partidos
    df[str(i[:-7])] = temp.iloc[:-1,1]
    df.drop('Potencial Votantes',axis=0)
df1=df.drop("Potencial Votantes").copy()
df2=df1.apply(pd.to_numeric).copy()

# %% [markdown]
# ## Base de datos completa

# %%
#Suma el total de cada Item en Bogotá y genera un archivo CSV con la información
dc=df2.copy()

dc["Total Bogota"]=dc.sum(axis=1)
total = dc.sum(axis=0)
total.name="Total votantes"
dfinal=dc.append(total).copy()
dfinal.to_csv("../Bogota/Votacion_Bogota_Unificada.csv")

# %%
dfinal
# Out:
#                       ANTONIO_NARINO  BARRIOS_UNIDOS    BOSA  CANDELARIA  \
# Gustavo Petro                  21561           19041  116017       10493
# Promotores Blanco                 81              88     390          32
# Ivan Duque                     19933           31154   57553        5346
# Humberto De la Calle            1767            3406    4272         953
# Jorge Trujillo                   190             322     904          64
# Sergio Fajardo                 24645           38973   67123        6701
# Viviane Morales                   92             135     536          35
# German Vargas Lleras            3392            6450    7495        1425
# Blanco                          1096            1410    4715         433
# Nulos                            453             372    3251         197
# No Marcados                       20              33     205          16
# Total votantes                 73230          101384  262461       25695
#
#                       CARCELES  CHAPINERO  CIUDAD_BOLIVAR  CORFERIAS  \
# Gustavo Petro              346      14595          118040      25766
# Promotores Blanco            2         40             339        174
# Ivan Duque                 127      37966           52252      23027
# Humberto De la Calle        15       4877            3743       1621
# Jorge Trujillo               3        102             857        197
# Sergio Fajardo             204      36914           52147      39184
# Viviane Morales              1         58             555        125
# German Vargas Lleras        17       7611            6722       2703
# Blanco                      17        837            4386       1587
# Nulos                       13        233            3680        608
# No Marcados                  2         24             275         26
# Total votantes             747     103257          242996      95018
#
#                       ENGATIVA  FONTIBON      ...       RAFAEL_URIBE_URIBE  \
# Gustavo Petro            96544     41217      ...                    69332
# Promotores Blanco          401       156      ...                      295
# Ivan Duque              104102     46647      ...                    37703
# Humberto De la Calle     11122      4973      ...                     3503
# Jorge Trujillo            1599       382      ...                      582
# Sergio Fajardo          165164     70681      ...                    48179
# Viviane Morales            573       231      ...                      288
# German Vargas Lleras     20689      9304      ...                     6313
# Blanco                    6597      2578      ...                     2911
# Nulos                     2161      1154      ...                     1813
# No Marcados                122        56      ...                      116
# Total votantes          409074    177379      ...                   171035
#
#                       SAN_CRISTOBAL  SANTA_FE    SUBA  SUMAPAZ  TEUSAQUILLO  \
# Gustavo Petro                 78389     21500  103163      994        21937
# Promotores Blanco               227        65     397        0           74
# Ivan Duque                    32949     11168  160250      166        31706
# Humberto De la Calle           3333      1809   13900       44         5286
# Jorge Trujillo                  584       164    1295        2          137
# Sergio Fajardo                45947     14118  195023       36        45629
# Viviane Morales                 353        67     586        2           93
# German Vargas Lleras           6170      2466   27211       28         8080
# Blanco                         3093       818    6712       14         1167
# Nulos                          2238       563    2438       10          219
# No Marcados                     130        39     206        3           20
# Total votantes               173413     52777  511181     1299       114348
#
#                       TUNJUELITO  USAQUEN    USME  Total Bogota
# Gustavo Petro              37204    34571   71227       1099955
# Promotores Blanco            103      153     173          3900
# Ivan Duque                 23581   114456   28862        989744
# Humberto De la Calle        1973     9624    2172         93401
# Jorge Trujillo               393      378     540         10696
# Sergio Fajardo             29033   110844   27662       1244477
# Viviane Morales              171      300     312          5492
# German Vargas Lleras        3791    19704    3777        172684
# Blanco                      1629     2793    2434         55867
# Nulos                        931      795    2197         27858
# No Marcados                   56       80     145          1885
# Total votantes             98865   293698  139501       3705959
#
# [12 rows x 23 columns]
